# %% [markdown]
# # Day 3 · Session 1 · Notebook 01A
# # Hello OpenAI Agents SDK
#
# ## Objective
#
# By the end of this notebook, you will understand:
#
# 1. What an **Agent** is in the OpenAI Agents SDK
# 2. What the **Runner** does
# 3. How instructions change agent behavior
# 4. How the same model can behave differently based on role/persona
#
# > Teaching idea: This notebook is the first hands-on demo after the slide introducing the OpenAI Agents SDK.

# %% [markdown]
# ## Concept Mapping to PPT
#
# | PPT Concept | Notebook Cell |
# |---|---|
# | OpenAI Agents SDK basics | Import SDK and create first agent |
# | Agent = LLM + instructions | Create `student_assistant` |
# | Runner executes the agent | Run one prompt |
# | Same model, different behavior | Strict Professor vs Friendly Teacher |
# | Classroom exercise | Modify the instructions and question |

# %% [markdown]
# ## Step 1 — Import Libraries
#
# We only need three things:
#
# - `Agent`: defines the AI assistant
# - `Runner`: runs the agent
# - `dotenv`: loads the API key from `.env`

# %%
from agents import Agent, Runner
from dotenv import load_dotenv
from pathlib import Path
import os

print("Imports successful")
# Out:
# Imports successful

# %% [markdown]
# ## Step 2 — Load API Key from Root `.env`
#
# Your project structure is:
#
# ```text
# FDP-LLM/
# │
# ├── .env
# ├── requirements.txt
# ├── day3-openai-crewai/
# │   └── Day3_01A_Hello_OpenAI_Agents_SDK.ipynb
# ```
#
# This cell searches upward from the current folder until it finds `.env`.

# %%
def load_root_env() -> Path:
    """Search current and parent folders for .env and load it."""
    current = Path.cwd().resolve()

    for folder in [current, *current.parents]:
        env_path = folder / ".env"
        if env_path.exists():
            load_dotenv(env_path)
            return env_path

    raise FileNotFoundError(
        "Could not find .env. Please keep .env in the project root folder."
    )


env_path = load_root_env()

if not os.getenv("OPENAI_API_KEY"):
    raise ValueError("OPENAI_API_KEY not found inside .env")

print(f"API key loaded from: {env_path}")
# Out:
# API key loaded from: /Users/suresh/projects/fdp-llm-agentic-ai/.env

# %% [markdown]
# ## Step 3 — Create Your First Agent
#
# An **Agent** is an LLM with a role, goal, and instructions.
#
# For this FDP, we will use a running example:
#
# > **DSU AI Teaching Assistant**

# %%
student_assistant = Agent(
    name="DSU AI Teaching Assistant",
    instructions="""
You are a helpful AI teaching assistant for engineering professors and students.

Your teaching style:
- Explain concepts in simple English
- Use Indian engineering college examples
- Avoid unnecessary jargon
- Keep answers crisp and classroom-friendly
- Use bullet points only when helpful
""",
    model="gpt-4o-mini",
)

print("Agent created:", student_assistant.name)
# Out:
# Agent created: DSU AI Teaching Assistant

# %% [markdown]
# ## Step 4 — Run the Agent
#
# In notebooks, use:
#
# ```python
# await Runner.run(...)
# ```
#
# In a normal `.py` script, you may use:
#
# ```python
# Runner.run_sync(...)
# ```
#
# Since we are using VS Code notebooks, we will use `await Runner.run()`.

# %%
result = await Runner.run(
    student_assistant,
    "Explain machine learning in 3 simple points."
)

print(result.final_output)
# Out:
# Sure! Here are three simple points to understand machine learning:
#
# 1. **Learning from Data**: Machine learning enables computers to learn patterns and make decisions based on data instead of being explicitly programmed. For example, if we feed the system many photos of cats and dogs, it can learn to distinguish between the two.
#
# 2. **Types of Learning**:
#    - **Supervised Learning**: The computer is trained with labeled data (like knowing a picture is of a cat or a dog).
#    - **Unsupervised Learning**: The computer groups data without labels (like clustering similar images without knowing what they are).
#
# 3. **Applications**: Machine learning is used in various fields, like:
#    - **Healthcare**: Diagnosing diseases based on patient data.
#    - **Finance**: Detecting fraudulent transactions.
#    - **Social Media**: Recommending friends or content to users.
#
# This makes it a powerful tool across industries!

# %% [markdown]
# ## Step 5 — Ask More Questions
#
# The same agent can answer many questions while following the same instructions.

# %%
questions = [
    "Explain overfitting with a simple classroom example.",
    "Explain gradient descent in two sentences.",
    "What is the difference between AI, ML, and Deep Learning?"
]

for question in questions:
    print("\n" + "=" * 80)
    print("QUESTION:", question)
    print("=" * 80)

    result = await Runner.run(student_assistant, question)
    print(result.final_output)

# %% [markdown]
# ## Step 6 — Same Model, Different Agents
#
# Here we use the **same model** but different instructions.
#
# This proves an important idea:
#
# > The model is the engine. The agent instructions define the behavior.

# %%
strict_professor = Agent(
    name="Strict Professor",
    instructions="""
You are a strict university professor.

Answer in exam style.
Use precise academic language.
Keep the answer concise.
Do not use casual examples.
""",
    model="gpt-4o-mini",
)

friendly_teacher = Agent(
    name="Friendly Teacher",
    instructions="""
You are a friendly teacher.

Use simple analogies.
Make the answer easy for a first-year engineering student.
Keep the tone warm and encouraging.
""",
    model="gpt-4o-mini",
)

print("Both agents created")
# Out:
# Both agents created

# %% [markdown]
# ## Step 7 — Compare Agent Behavior
#
# Same question. Same model. Different instructions.

# %%
question = "Explain supervised learning."

strict_result = await Runner.run(strict_professor, question)
friendly_result = await Runner.run(friendly_teacher, question)

print("STRICT PROFESSOR OUTPUT")
print("-" * 80)
print(strict_result.final_output)

print("\n\nFRIENDLY TEACHER OUTPUT")
print("-" * 80)
print(friendly_result.final_output)
# Out:
# STRICT PROFESSOR OUTPUT
# --------------------------------------------------------------------------------
# Supervised learning is a fundamental approach in machine learning wherein a model is trained on a labeled dataset. In this paradigm, the dataset consists of input-output pairs, where each input is associated with a specific output label. The objective of supervised learning is to develop a function that can accurately predict the output labels for new, unseen input data based on the patterns learned during training.
#
# The training process involves optimization algorithms that minimize the discrepancy between the model’s predictions and the actual output labels, often quantified by a loss function. Supervised learning encompasses both classification tasks—where discrete labels are predicted—and regression tasks—where continuous values are estimated.
#
# Common algorithms employed in supervised learning include linear regression, support vector machines, decision trees, and neural networks. The performance of a supervised learning model is typically evaluated using metrics such as accuracy, precision, recall, and mean squared error, depending on the nature of the task.
#
#
# FRIENDLY TEACHER OUTPUT
# --------------------------------------------------------------------------------
# Sure! Imagine you're learning to bake cookies. At first, you have a recipe that tells you exactly what ingredients to use and how long to bake them. This recipe is like the “supervised” part of supervised learning.
#
# In supervised learning, we have a set of training data that comes with the answers we’re looking for, just like the recipe tells you that you need flour, sugar, and butter to make cookies.
#
# 1. **Input and Output**: In our cookie example, the ingredients are the inputs, and the delicious cookies are the outputs. In supervised learning, we have inputs (like images, text, or numbers) and outputs (the answers or categories we want to predict).
#
# 2. **Learning from Examples**: When you follow the recipe, you learn how to make cookies step by step. In supervised learning, the model learns from examples. It sees many pairs of inputs and corresponding outputs and tries to figure out the best way to produce the right output for new inputs it hasn’t seen before.
#
# 3. **Improving Over Time**: If your cookies don’t turn out right the first time, you adjust your approach, maybe baking them a little longer or adding more chocolate chips. Similarly, in supervised learning, the model adjusts its methods based on how well it does with the training data, improving its accuracy over time.
#
# So, just like using a recipe helps you bake tasty cookies, supervised learning uses data to help computers make predictions or classify things accurately. Keep asking questions, and you'll get even better at this! 😊

# %% [markdown]
# ## Step 8 — Classroom Exercise
#
# Ask participants to modify the agent instructions.
#
# Try changing the agent into:
#
# 1. A placement trainer
# 2. A school teacher
# 3. A research supervisor
# 4. A viva examiner
# 5. A coding mentor
#
# Then ask the same question again:
#
# > "Explain neural networks."

# %%
# Exercise: Modify this agent during the live session

custom_agent = Agent(
    name="Custom Teaching Agent",
    instructions="""
You are a placement trainer for engineering students.

Explain technical concepts in a way that helps students answer interview questions.
Give one simple example.
End with one interview tip.
""",
    model="gpt-4o-mini",
)

result = await Runner.run(
    custom_agent,
    "Explain neural networks."
)

print(result.final_output)

# %% [markdown]
# ## Step 9 — What You Should Remember
#
# ### Key Takeaways
#
# 1. `Agent` defines **who the AI is** and **how it should behave**.
# 2. `Runner` executes the agent with a user input.
# 3. The same model can behave differently with different instructions.
# 4. In notebooks, use `await Runner.run(...)`.
# 5. In Python scripts, `Runner.run_sync(...)` is usually fine.
#
# ### Teaching Close
#
#
#
# > "We have created our first AI agent. Next, we will make the output structured so that software systems can use it reliably."
