# %% [markdown]
# # Day3_01C_Function_Tools
# ## OpenAI Agents SDK - Teaching Notebook
#
# **Duration:** 20 minutes
#
# ### Learning Objectives
# - Understand why AI Agents need tools.
# - Create Function Tools.
# - Build Agents with one and multiple tools.
# - Use classroom-friendly DSU examples.

# %% [markdown]
# ## 1. Why Do Agents Need Tools?
# LLMs are excellent at reasoning, but they cannot directly access live systems like databases, APIs, emails, or files. Agents become useful by invoking **Tools** to perform these actions.

# %%
from pathlib import Path
from dotenv import load_dotenv
import os

from agents import Agent, Runner, function_tool

# %% [markdown]
# ## 2. Load Environment Variables

# %%
current = Path.cwd().resolve()

for folder in [current] + list(current.parents):
    env = folder / ".env"
    if env.exists():
        load_dotenv(env)
        break

print("API Key Loaded:", os.getenv("OPENAI_API_KEY") is not None)
# Out:
# API Key Loaded: True

# %% [markdown]
# ## 3. Create Your First Function Tool

# %%
@function_tool
def multiply(a: int, b: int) -> int:
    """
    Multiply two numbers.
    """
    return a * b

# %% [markdown]
# ### What did we just learn?
# - `@function_tool` exposes a Python function to the Agent.
# - The docstring helps the LLM understand when to use it.
# - Type hints describe the expected inputs.

# %% [markdown]
# ## 4. Create an Agent

# %%
math_agent = Agent(
    name="Math Assistant",
    instructions="You are a helpful mathematics assistant.",
    tools=[multiply],
)

# %% [markdown]
# ## 5. Run the Agent

# %%
result = Runner.run_sync(
    math_agent,
    "What is 27 multiplied by 53?"
)

print(result.final_output)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 result = Runner.run_sync(
#       2     math_agent,
#       3     "What is 27 multiplied by 53?"
#       4 )
#
# File ~/Projects/teaching/fdp-llm-agentic-ai/.venv/lib/python3.12/site-packages/agents/run.py:351, in Runner.run_sync(cls, starting_agent, input, context, max_turns, hooks, run_config, error_handlers, previous_response_id, auto_previous_response_id, conversation_id, session)
#     299 """
#     300 Run a workflow synchronously, starting at the given agent.
#     301
#    (...)    347     type of the output.
#     348 """
#     350 runner = DEFAULT_AGENT_RUNNER
# --> 351 return runner.run_sync(
#     352     starting_agent,
#     353     input,
#     354     context=context,
#     355     max_turns=max_turns,
#     356     hooks=hooks,
#     357     run_config=run_config,
#     358     error_handlers=error_handlers,
#     359     previous_response_id=previous_response_id,
#     360     conversation_id=conversation_id,
#     361     session=session,
#     362     auto_previous_response_id=auto_previous_response_id,
#     363 )
#
# File ~/Projects/teaching/fdp-llm-agentic-ai/.venv/lib/python3.12/site-packages/agents/run.py:1599, in AgentRunner.run_sync(self, starting_agent, input, **kwargs)
#    1593     already_running_loop = None
#    1595 if already_running_loop is not None:
#    1596     # This method is only expected to run when no loop is already active.
#    1597     # (Each thread has its own default loop; concurrent sync runs should happen on
#    1598     # different threads. In a single thread use the async API to interleave work.)
# -> 1599     raise RuntimeError(
#    1600         "AgentRunner.run_sync() cannot be called when an event loop is already running."
#    1601     )
#    1603 policy = asyncio.get_event_loop_policy()
#    1604 with warnings.catch_warnings():
#
# RuntimeError: AgentRunner.run_sync() cannot be called when an event loop is already running.

# %% [markdown]
# ### Pause & Reflect
# Notice that we never called `multiply()` directly. The Agent decided to invoke the tool.

# %% [markdown]
# ## 6. Create Another Tool

# %%
@function_tool
def faculty_directory(department: str) -> str:
    """
    Returns faculty members for a department.
    """
    directory = {
        "AI&ML": "Prof. Arun, Prof. Meena",
        "CSE": "Prof. Kumar, Prof. Rekha",
        "ECE": "Prof. Ramesh, Prof. Divya"
    }

    return directory.get(department.upper(), "Department not found.")

# %% [markdown]
# ## 7. Agent with Multiple Tools

# %%
college_agent = Agent(
    name="DSU Assistant",
    instructions="You help faculty answer questions about the college.",
    tools=[multiply, faculty_directory],
)

# %%
response = Runner.run_sync(
    college_agent,
    "Who teaches in AI&ML?"
)

print(response.final_output)

response = Runner.run_sync(
    college_agent,
    "Calculate 84 multiplied by 19."
)

print(response.final_output)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 response = Runner.run_sync(
#       2     college_agent,
#       3     "Who teaches in AI&ML?"
#       4 )
#
# File ~/Projects/teaching/fdp-llm-agentic-ai/.venv/lib/python3.12/site-packages/agents/run.py:351, in Runner.run_sync(cls, starting_agent, input, context, max_turns, hooks, run_config, error_handlers, previous_response_id, auto_previous_response_id, conversation_id, session)
#     299 """
#     300 Run a workflow synchronously, starting at the given agent.
#     301
#    (...)    347     type of the output.
#     348 """
#     350 runner = DEFAULT_AGENT_RUNNER
# --> 351 return runner.run_sync(
#     352     starting_agent,
#     353     input,
#     354     context=context,
#     355     max_turns=max_turns,
#     356     hooks=hooks,
#     357     run_config=run_config,
#     358     error_handlers=error_handlers,
#     359     previous_response_id=previous_response_id,
#     360     conversation_id=conversation_id,
#     361     session=session,
#     362     auto_previous_response_id=auto_previous_response_id,
#     363 )
#
# File ~/Projects/teaching/fdp-llm-agentic-ai/.venv/lib/python3.12/site-packages/agents/run.py:1599, in AgentRunner.run_sync(self, starting_agent, input, **kwargs)
#    1593     already_running_loop = None
#    1595 if already_running_loop is not None:
#    1596     # This method is only expected to run when no loop is already active.
#    1597     # (Each thread has its own default loop; concurrent sync runs should happen on
#    1598     # different threads. In a single thread use the async API to interleave work.)
# -> 1599     raise RuntimeError(
#    1600         "AgentRunner.run_sync() cannot be called when an event loop is already running."
#    1601     )
#    1603 policy = asyncio.get_event_loop_policy()
#    1604 with warnings.catch_warnings():
#
# RuntimeError: AgentRunner.run_sync() cannot be called when an event loop is already running.

# %% [markdown]
# ## 8. Enterprise Connection
# Typical enterprise tools include CRM lookup, Ticket APIs, Knowledge Bases, Email Senders, and ERP systems.

# %% [markdown]
# ## 9. Hands-on Exercise
# Create a new tool called `college_info()` that returns library timings, principal name, and campus address.

# %% [markdown]
# ## 10. Challenge Exercise
# Create another tool called `canteen_menu()` and ask the Agent: *What's available for lunch today?*

# %% [markdown]
# ## Key Takeaways
# - Tools connect Agents with the real world.
# - Agents decide which tool to use.
# - One Agent can use multiple tools.
# - Good tool descriptions improve tool selection.
